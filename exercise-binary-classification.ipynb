# %% [markdown]
# <a href="https://www.kaggle.com/code/an1ndya/exercise-binary-classification?scriptVersionId=159522766" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# **This notebook is an exercise in the [Intro to Deep Learning](https://www.kaggle.com/learn/intro-to-deep-learning) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/binary-classification).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In this exercise, you'll build a model to predict hotel cancellations with a binary classifier.

# %%
# Setup plotting
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.deep_learning_intro.ex6 import *
# Out:
# /tmp/ipykernel_26/3338970720.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %% [markdown]
# First, load the *Hotel Cancellations* dataset.

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('../input/dl-course-data/hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# stratify - make sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # 1) Define Model #
#
# The model we'll use this time will have both batch normalization and dropout layers. To ease reading we've broken the diagram into blocks, but you can define it layer by layer as usual.
#
# Define a model with an architecture given by this diagram:
#
# <figure style="padding: 1em;">
# <img src="https://storage.googleapis.com/kaggle-media/learn/images/V04o59Z.png" width="400" alt="Diagram of network architecture: BatchNorm, Dense, BatchNorm, Dropout, Dense, BatchNorm, Dropout, Dense.">
# <figcaption style="textalign: center; font-style: italic"><center>Diagram of a binary classifier.</center></figcaption>
# </figure>

# %%
from tensorflow import keras
from tensorflow.keras import layers

# YOUR CODE HERE: define the model given in the diagram
model = keras.Sequential([
    layers.BatchNormalization(input_shape = input_shape),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(1, activation='sigmoid'),
])

# Check your answer
q_1.check()
# Out:
# Correct

# %% [markdown]
# # 2) Add Optimizer, Loss, and Metric #
#
# Now compile the model with the Adam optimizer and binary versions of the cross-entropy loss and accuracy metric.

# %%
# YOUR CODE HERE
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)

# Check your answer
q_2.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
q_2.hint()
q_2.solution()
# Out:
# Hint: Your code should look something like:
# ```python
# model.compile(
# optimizer=____,
# loss=____,
# metrics=____,
# )
# ```
# Solution:
# ```python
#
# model.compile(
#     optimizer='adam',
#     loss='binary_crossentropy',
#     metrics=['binary_accuracy'],
# )
#
# ```

# %% [markdown]
# Finally, run this cell to train the model and view the learning curves. It may run for around 60 to 70 epochs, which could take a minute or two.

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
# Out:
# Epoch 1/200
# 175/175 [==============================] - 6s 9ms/step - loss: 0.4799 - binary_accuracy: 0.7729 - val_loss: 0.4291 - val_binary_accuracy: 0.8066
# Epoch 2/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.4241 - binary_accuracy: 0.8009 - val_loss: 0.4010 - val_binary_accuracy: 0.8124
# Epoch 3/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.4106 - binary_accuracy: 0.8073 - val_loss: 0.3924 - val_binary_accuracy: 0.8161
# Epoch 4/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.4020 - binary_accuracy: 0.8128 - val_loss: 0.3873 - val_binary_accuracy: 0.8206
# Epoch 5/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3984 - binary_accuracy: 0.8144 - val_loss: 0.3838 - val_binary_accuracy: 0.8224
# Epoch 6/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3936 - binary_accuracy: 0.8174 - val_loss: 0.3804 - val_binary_accuracy: 0.8238
# Epoch 7/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3899 - binary_accuracy: 0.8190 - val_loss: 0.3777 - val_binary_accuracy: 0.8252
# Epoch 8/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3864 - binary_accuracy: 0.8201 - val_loss: 0.3774 - val_binary_accuracy: 0.8259
# Epoch 9/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3827 - binary_accuracy: 0.8232 - val_loss: 0.3728 - val_binary_accuracy: 0.8268
# Epoch 10/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3795 - binary_accuracy: 0.8255 - val_loss: 0.3705 - val_binary_accuracy: 0.8281
# Epoch 11/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3773 - binary_accuracy: 0.8259 - val_loss: 0.3709 - val_binary_accuracy: 0.8315
# Epoch 12/200
# 175/175 [==============================] - 1s 8ms/step - loss: 0.3745 - binary_accuracy: 0.8273 - val_loss: 0.3670 - val_binary_accuracy: 0.8313
# Epoch 13/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3720 - binary_accuracy: 0.8283 - val_loss: 0.3654 - val_binary_accuracy: 0.8310
# Epoch 14/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3710 - binary_accuracy: 0.8291 - val_loss: 0.3668 - val_binary_accuracy: 0.8322
# Epoch 15/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3676 - binary_accuracy: 0.8299 - val_loss: 0.3621 - val_binary_accuracy: 0.8342
# Epoch 16/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3667 - binary_accuracy: 0.8311 - val_loss: 0.3644 - val_binary_accuracy: 0.8321
# Epoch 17/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3663 - binary_accuracy: 0.8312 - val_loss: 0.3598 - val_binary_accuracy: 0.8349
# Epoch 18/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3643 - binary_accuracy: 0.8320 - val_loss: 0.3591 - val_binary_accuracy: 0.8353
# Epoch 19/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3615 - binary_accuracy: 0.8331 - val_loss: 0.3588 - val_binary_accuracy: 0.8343
# Epoch 20/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3601 - binary_accuracy: 0.8345 - val_loss: 0.3583 - val_binary_accuracy: 0.8344
# Epoch 21/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3579 - binary_accuracy: 0.8340 - val_loss: 0.3576 - val_binary_accuracy: 0.8363
# Epoch 22/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3573 - binary_accuracy: 0.8352 - val_loss: 0.3554 - val_binary_accuracy: 0.8354
# Epoch 23/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3549 - binary_accuracy: 0.8353 - val_loss: 0.3524 - val_binary_accuracy: 0.8375
# Epoch 24/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3538 - binary_accuracy: 0.8363 - val_loss: 0.3597 - val_binary_accuracy: 0.8332
# Epoch 25/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3535 - binary_accuracy: 0.8370 - val_loss: 0.3533 - val_binary_accuracy: 0.8379
# Epoch 26/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3515 - binary_accuracy: 0.8388 - val_loss: 0.3520 - val_binary_accuracy: 0.8391
# Epoch 27/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3510 - binary_accuracy: 0.8383 - val_loss: 0.3519 - val_binary_accuracy: 0.8380
# Epoch 28/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3495 - binary_accuracy: 0.8382 - val_loss: 0.3494 - val_binary_accuracy: 0.8408
# Epoch 29/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3496 - binary_accuracy: 0.8386 - val_loss: 0.3526 - val_binary_accuracy: 0.8388
# Epoch 30/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3472 - binary_accuracy: 0.8405 - val_loss: 0.3516 - val_binary_accuracy: 0.8381
# Epoch 31/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3464 - binary_accuracy: 0.8404 - val_loss: 0.3527 - val_binary_accuracy: 0.8378
# Epoch 32/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3458 - binary_accuracy: 0.8403 - val_loss: 0.3509 - val_binary_accuracy: 0.8387
# Epoch 33/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3450 - binary_accuracy: 0.8413 - val_loss: 0.3491 - val_binary_accuracy: 0.8399
# <Axes: title={'center': 'Accuracy'}>

# %% [markdown]
# # 3) Train and Evaluate #
#
#
# What do you think about the learning curves? Does it look like the model underfit or overfit? Was the cross-entropy loss a good stand-in for accuracy?

# %%
# View the solution (Run this cell to receive credit!)
q_3.check()
# Out:
# Correct:
#
# Though we can see the training loss continuing to fall, the early stopping callback prevented any overfitting. Moreover, the accuracy rose at the same rate as the cross-entropy fell, so it appears that minimizing cross-entropy was a good stand-in. All in all, it looks like this training was a success!

# %% [markdown]
# # Conclusion #
#
# Congratulations! You've completed Kaggle's *Introduction to Deep Learning* course!
#
# With your new skills you're ready to take on more advanced applications like computer vision and sentiment classification. What would you like to do next?
#
# Why not try one of our *Getting Started* competitions?
#
# - Classify images with TPUs in [**Petals to the Metal**](https://www.kaggle.com/c/tpu-getting-started)
# - Create art with GANs in [**I'm Something of a Painter Myself**](https://www.kaggle.com/c/gan-getting-started)
# - Classify Tweets in [**Real or Not? NLP with Disaster Tweets**](https://www.kaggle.com/c/nlp-getting-started)
# - Detect contradiction and entailment in [**Contradictory, My Dear Watson**](https://www.kaggle.com/c/contradictory-my-dear-watson)
#
# Until next time, Kagglers!

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/intro-to-deep-learning/discussion) to chat with other learners.*
